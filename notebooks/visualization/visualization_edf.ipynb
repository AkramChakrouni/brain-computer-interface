# %%
import numpy as np
import mne
import os
import pandas as pd
from scipy.signal import iirfilter, sosfilt
from scipy.signal import iirfilter, lfilter
import pyedflib

# MNE imports
from mne.preprocessing import ICA
from mne.preprocessing import create_eog_epochs
from mne.preprocessing import read_ica
from mne.preprocessing import compute_proj_eog

# %%
# Loading edf file, relative path
file_path = r"C:\School\EE_Y3\Q4\BAP\eeg_thesis_cnn_repo\data\openvibe\raw\record-[2024.05.29-15.06.48]_FILTERED.edf"
data_path = os.path.join('..', '..', file_path)

# Read the file
own = mne.io.read_raw_edf(data_path, preload=True)

own.ch_names
# Out:
# Extracting EDF parameters from C:\School\EE_Y3\Q4\BAP\eeg_thesis_cnn_repo\data\openvibe\raw\record-[2024.05.29-15.06.48]_FILTERED.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 36749  =      0.000 ...   146.996 secs...
# C:\Users\chakr\AppData\Local\Temp\ipykernel_2824\3190953648.py:6: RuntimeWarning: Invalid patient information
#   own = mne.io.read_raw_edf(data_path, preload=True)
# ['FP1', 'FP2', 'F3', 'F2', 'C3', 'C4', 'P3', 'P4']

# %%
own.plot_psd()
# Out:
# NOTE: plot_psd() is a legacy function. New code should use .compute_psd().plot().
# Effective window size : 8.192 (s)
# C:\Users\chakr\AppData\Local\Temp\ipykernel_22360\3432080872.py:1: RuntimeWarning: Channel locations not available. Disabling spatial colors.
#   own.plot_psd()
# c:\Users\chakr\Anaconda3\envs\eeg_thesis\lib\site-packages\mne\viz\utils.py:165: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   (fig or plt).show(**kwargs)
# <MNELineFigure size 1000x350 with 1 Axes>

# %%
filtered.plot(scalings='auto', duration=10, n_channels=64)
# Out:
# <MNEBrowseFigure size 800x800 with 4 Axes>
# <MNEBrowseFigure size 800x800 with 4 Axes>
